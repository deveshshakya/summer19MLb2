# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
cv2.__version__
# %matplotlib inline

# %%
img = cv2.imread('bmw_motorrad_vision_dc_roadster_2019_4k_2-360x640.jpg')

# %%
cv2_imshow(img, )

# %%
b, g, r = cv2.split(img)

# %%
cv2_imshow(b)

# %%
cv2_imshow(g)

# %%
cv2_imshow(r)

# %%
cv2_imshow(cv2.line(img, (20, 20), (40, 40), (0, 0, 255), 3))
# Out:
# <PIL.Image.Image image mode=RGB size=360x640 at 0x7FF416E54AC8>

# %%
cv2_imshow(cv2.rectangle(img, (40, 40), (120, 120), (0, 0, 255), -1))
# Out:
# <PIL.Image.Image image mode=RGB size=360x640 at 0x7FF416E54160>

# %%
cv2_imshow(cv2.circle(img, (20, 20), 20, (0, 255, 0)))
# Out:
# <PIL.Image.Image image mode=RGB size=360x640 at 0x7FF416E54438>
