# %%
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
x = [4, 7, 8, 9, 11, 5]
y = [13, 23, 5, 7, 9, 3]
players = ['virat', 'dhoni', 'vijay', 'dhawan']
runs = [120, 44, 77, 50]
exp = [0.1, 0, 0, 0.2]

# %%
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.plot(x, y) # For line plot
# plt.bar(x, y, label='polution')
# plt.bar(players, runs, label='cricket_score')
plt.scatter(x, y) # For dots
plt.grid(color='green')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.plot(x, y) # For line plot
# plt.bar(x, y, label='polution')
# plt.bar(players, runs, label='cricket_score')
# plt.scatter(x, y) # For dots
# plt.grid(color='green')
plt.pie(runs, labels=players, explode=exp, shadow=True, autopct='1.1')
# plt.legend()
plt.show()
